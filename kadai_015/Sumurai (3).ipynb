# %%
class Human:
    # コンストラクタを定義する
    def __init__(self, name, age):
        self.name = name
        self.age = age

# インスタンス化する
printinfo = Human("侍太郎", 36)

# 属性にアクセスし、値を出力する
print(printinfo.name)
print(printinfo.age)
# Out:
# 侍太郎
# 36
