# %%
class Human:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    # メソッドを定義する
    def printinfo(self):
        print(self.name)
        print(self.age)

# インスタンス化する
human = Human("ichiro", 20)

# メソッドにアクセスして実行する
human.printinfo()
# Out:
# ichiro
# 20
