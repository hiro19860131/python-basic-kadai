# %%
import random

num = random.randint(0,20)

print(num)

if num % 3 == 0 and num % 5 == 0:
    print("FizzBuzz")

elif num % 3 == 0:
    print("Fizz")

elif num % 5 == 0:
    print("Buzz")
# Out:
# 6
# Fizz
