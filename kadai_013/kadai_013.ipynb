# %%
def calculate_total (price):
    total = int(price * 1.1)
    total_tax = int(price * 0.1)

    print(f"合計 {total}")
    print(f"消費税 {total_tax}")


calculate_total(100)
# Out:
# 合計 110
# 消費税 10
